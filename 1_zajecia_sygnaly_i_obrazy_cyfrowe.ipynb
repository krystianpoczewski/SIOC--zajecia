# %% [markdown]
# <a href="https://colab.research.google.com/github/krystianpoczewski/SIOC-1-zajecia/blob/main/1_zajecia_sygnaly_i_obrazy_cyfrowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import skimage
from skimage import io

image = io.imread('pobrane.jpg')


newPic = skimage.transform.rotate(image, 180)

io.imshow(newPic);
